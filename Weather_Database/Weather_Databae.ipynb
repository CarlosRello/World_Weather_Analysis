# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 623

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | torbay
# Processing Record 3 of Set 1 | comodoro rivadavia
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | kieta
# Processing Record 9 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | great bend
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | hirara
# Processing Record 15 of Set 1 | moyale
# Processing Record 16 of Set 1 | rocha
# Processing Record 17 of Set 1 | luderitz
# Processing Record 18 of Set 1 | plettenberg bay
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | nakamura
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | port hardy
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | goderich
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | mehamn
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | leningradskiy
# Processing Record 35 of Set 1 | tarko-sale
# Processing Record 36 of Set 1 | mlandizi
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | havre-saint-pierre
# Processing Record 40 of Set 1 | usinsk
# Processing Record 41 of Set 1 | lebu
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | arrifes
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | chokurdakh
# Processing Record 46 of Set 1 | vardo
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | juifang
# City not found. Skipping...
# Processing Record 2 of Set 2 | pringsewu
# Processing Record 3 of Set 2 | morgan city
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | azimur
# City not found. Skipping...
# Processing Record 6 of Set 2 | turtas
# Processing Record 7 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 2 | mar del plata
# Processing Record 9 of Set 2 | winnemucca
# Processing Record 10 of Set 2 | santa maria
# Processing Record 11 of Set 2 | kupang
# Processing Record 12 of Set 2 | tchaourou
# Processing Record 13 of Set 2 | pangnirtung
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | springfield
# Processing Record 16 of Set 2 | dunedin
# Processing Record 17 of Set 2 | soe
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | nizwa
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | gamba
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | walvis bay
# Processing Record 29 of Set 2 | bac lieu
# Processing Record 30 of Set 2 | liuzhou
# Processing Record 31 of Set 2 | whitehorse
# Processing Record 32 of Set 2 | banda aceh
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | vao
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 2 | swan river
# Processing Record 39 of Set 2 | jining
# Processing Record 40 of Set 2 | kloulklubed
# Processing Record 41 of Set 2 | havoysund
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | nyurba
# Processing Record 44 of Set 2 | ahipara
# Processing Record 45 of Set 2 | college
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | maxixe
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | christchurch
# Processing Record 50 of Set 2 | saldanha
# Processing Record 1 of Set 3 | banihal
# Processing Record 2 of Set 3 | sur
# Processing Record 3 of Set 3 | caronport
# Processing Record 4 of Set 3 | vilyuysk
# Processing Record 5 of Set 3 | gilbues
# Processing Record 6 of Set 3 | tabas
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | naze
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 3 | labrea
# Processing Record 14 of Set 3 | bambous virieux
# Processing Record 15 of Set 3 | cabedelo
# Processing Record 16 of Set 3 | hervey bay
# Processing Record 17 of Set 3 | bassano
# Processing Record 18 of Set 3 | labuhan
# Processing Record 19 of Set 3 | sakiai
# Processing Record 20 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | butte
# Processing Record 23 of Set 3 | tezu
# Processing Record 24 of Set 3 | senno
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | roros
# Processing Record 27 of Set 3 | novikovo
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | aripuana
# Processing Record 30 of Set 3 | beyneu
# Processing Record 31 of Set 3 | portland
# Processing Record 32 of Set 3 | ust-koksa
# Processing Record 33 of Set 3 | bhatkal
# Processing Record 34 of Set 3 | wangqing
# Processing Record 35 of Set 3 | kimbe
# Processing Record 36 of Set 3 | vestmannaeyjar
# Processing Record 37 of Set 3 | kodiak
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | evensk
# Processing Record 41 of Set 3 | coihaique
# Processing Record 42 of Set 3 | lorengau
# Processing Record 43 of Set 3 | hamilton
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | arteaga
# Processing Record 46 of Set 3 | udachnyy
# Processing Record 47 of Set 3 | hongjiang
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | megion
# Processing Record 50 of Set 3 | lonavale
# Processing Record 1 of Set 4 | sao jose da coroa grande
# Processing Record 2 of Set 4 | tres arroyos
# Processing Record 3 of Set 4 | bairiki
# Processing Record 4 of Set 4 | tiksi
# Processing Record 5 of Set 4 | klaksvik
# Processing Record 6 of Set 4 | tabuk
# Processing Record 7 of Set 4 | barra do garcas
# Processing Record 8 of Set 4 | kwidzyn
# Processing Record 9 of Set 4 | amapa
# Processing Record 10 of Set 4 | pontypool
# Processing Record 11 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 4 | samarinda
# Processing Record 13 of Set 4 | guerrero negro
# Processing Record 14 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 4 | port elizabeth
# Processing Record 16 of Set 4 | umm lajj
# Processing Record 17 of Set 4 | vagur
# Processing Record 18 of Set 4 | olga
# Processing Record 19 of Set 4 | upernavik
# Processing Record 20 of Set 4 | yerbogachen
# Processing Record 21 of Set 4 | faya
# Processing Record 22 of Set 4 | arinos
# Processing Record 23 of Set 4 | gat
# Processing Record 24 of Set 4 | danjiangkou
# Processing Record 25 of Set 4 | sao joao da barra
# Processing Record 26 of Set 4 | tasiilaq
# Processing Record 27 of Set 4 | dwarka
# Processing Record 28 of Set 4 | gouyave
# Processing Record 29 of Set 4 | tual
# Processing Record 30 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | haines junction
# Processing Record 33 of Set 4 | canico
# Processing Record 34 of Set 4 | santiago del estero
# Processing Record 35 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | vilaka
# Processing Record 38 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 4 | harper
# Processing Record 40 of Set 4 | airai
# Processing Record 41 of Set 4 | plaridel
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | launceston
# Processing Record 44 of Set 4 | arzgir
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | skjervoy
# Processing Record 47 of Set 4 | longyearbyen
# Processing Record 48 of Set 4 | bandarbeyla
# Processing Record 49 of Set 4 | katangli
# Processing Record 50 of Set 4 | nome
# Processing Record 1 of Set 5 | muzaffarabad
# Processing Record 2 of Set 5 | goundi
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | awbari
# Processing Record 5 of Set 5 | hakvik
# City not found. Skipping...
# Processing Record 6 of Set 5 | cockburn town
# Processing Record 7 of Set 5 | kuching
# Processing Record 8 of Set 5 | gizo
# Processing Record 9 of Set 5 | jibuti
# Processing Record 10 of Set 5 | ruston
# Processing Record 11 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | shenjiamen
# Processing Record 13 of Set 5 | qaqortoq
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 5 | saint-pierre
# Processing Record 17 of Set 5 | victoria
# Processing Record 18 of Set 5 | wernigerode
# Processing Record 19 of Set 5 | karratha
# Processing Record 20 of Set 5 | kingaroy
# Processing Record 21 of Set 5 | magaria
# Processing Record 22 of Set 5 | acapulco
# Processing Record 23 of Set 5 | mareeba
# Processing Record 24 of Set 5 | itarema
# Processing Record 25 of Set 5 | oktyabrskoye
# Processing Record 26 of Set 5 | maragogi
# Processing Record 27 of Set 5 | laguna
# Processing Record 28 of Set 5 | mogadishu
# Processing Record 29 of Set 5 | san quintin
# Processing Record 30 of Set 5 | kemin
# Processing Record 31 of Set 5 | roebourne
# Processing Record 32 of Set 5 | tobol
# Processing Record 33 of Set 5 | sonoma
# Processing Record 34 of Set 5 | boshnyakovo
# Processing Record 35 of Set 5 | huarmey
# Processing Record 36 of Set 5 | kells
# Processing Record 37 of Set 5 | kota kinabalu
# Processing Record 38 of Set 5 | broken hill
# Processing Record 39 of Set 5 | lamu
# Processing Record 40 of Set 5 | asmara
# Processing Record 41 of Set 5 | zaysan
# Processing Record 42 of Set 5 | codrington
# Processing Record 43 of Set 5 | vila franca do campo
# Processing Record 44 of Set 5 | verkhnyaya inta
# Processing Record 45 of Set 5 | the valley
# Processing Record 46 of Set 5 | nouadhibou
# Processing Record 47 of Set 5 | ormara
# Processing Record 48 of Set 5 | husavik
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | oksfjord
# Processing Record 1 of Set 6 | burns lake
# Processing Record 2 of Set 6 | la ronge
# Processing Record 3 of Set 6 | boguchany
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | coquimbo
# Processing Record 6 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 6 | acajutla
# Processing Record 8 of Set 6 | waingapu
# Processing Record 9 of Set 6 | oussouye
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | zhigansk
# Processing Record 12 of Set 6 | raduzhnyy
# Processing Record 13 of Set 6 | batemans bay
# Processing Record 14 of Set 6 | kiama
# Processing Record 15 of Set 6 | chuy
# Processing Record 16 of Set 6 | hobyo
# Processing Record 17 of Set 6 | ambulu
# Processing Record 18 of Set 6 | calama
# Processing Record 19 of Set 6 | georgetown
# Processing Record 20 of Set 6 | kavieng
# Processing Record 21 of Set 6 | praia
# Processing Record 22 of Set 6 | tymovskoye
# Processing Record 23 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 6 | katubao
# Processing Record 26 of Set 6 | awjilah
# Processing Record 27 of Set 6 | mount gambier
# Processing Record 28 of Set 6 | muli
# Processing Record 29 of Set 6 | muroto
# Processing Record 30 of Set 6 | ambilobe
# Processing Record 31 of Set 6 | qasigiannguit
# Processing Record 32 of Set 6 | sibolga
# Processing Record 33 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 6 | marsh harbour
# Processing Record 35 of Set 6 | maldonado
# Processing Record 36 of Set 6 | leku
# Processing Record 37 of Set 6 | ilheus
# Processing Record 38 of Set 6 | ambon
# Processing Record 39 of Set 6 | ixtapa
# Processing Record 40 of Set 6 | ucluelet
# Processing Record 41 of Set 6 | saurimo
# Processing Record 42 of Set 6 | ouallam
# Processing Record 43 of Set 6 | leeds
# Processing Record 44 of Set 6 | baruun-urt
# Processing Record 45 of Set 6 | westport
# Processing Record 46 of Set 6 | dikson
# Processing Record 47 of Set 6 | quatre cocos
# Processing Record 48 of Set 6 | atherton
# Processing Record 49 of Set 6 | sosnovo-ozerskoye
# Processing Record 50 of Set 6 | lodja
# Processing Record 1 of Set 7 | killybegs
# Processing Record 2 of Set 7 | saint george
# Processing Record 3 of Set 7 | chapais
# Processing Record 4 of Set 7 | bonavista
# Processing Record 5 of Set 7 | hasaki
# Processing Record 6 of Set 7 | ponta delgada
# Processing Record 7 of Set 7 | barabai
# Processing Record 8 of Set 7 | samastipur
# Processing Record 9 of Set 7 | sistranda
# Processing Record 10 of Set 7 | tulsipur
# Processing Record 11 of Set 7 | alta floresta
# Processing Record 12 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 7 | hoi an
# Processing Record 14 of Set 7 | kushmurun
# Processing Record 15 of Set 7 | palembang
# Processing Record 16 of Set 7 | kaitangata
# Processing Record 17 of Set 7 | jacareacanga
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | kitui
# Processing Record 20 of Set 7 | makakilo city
# Processing Record 21 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 7 | ternate
# Processing Record 23 of Set 7 | nara
# Processing Record 24 of Set 7 | saskylakh
# Processing Record 25 of Set 7 | komsomolskiy
# Processing Record 26 of Set 7 | novyy urgal
# Processing Record 27 of Set 7 | manakara
# Processing Record 28 of Set 7 | rizhao
# Processing Record 29 of Set 7 | kirakira
# Processing Record 30 of Set 7 | valparaiso
# Processing Record 31 of Set 7 | merauke
# Processing Record 32 of Set 7 | sitka
# Processing Record 33 of Set 7 | pucallpa
# Processing Record 34 of Set 7 | mbandaka
# Processing Record 35 of Set 7 | nuuk
# Processing Record 36 of Set 7 | baherden
# Processing Record 37 of Set 7 | sinnamary
# Processing Record 38 of Set 7 | waycross
# Processing Record 39 of Set 7 | gavle
# Processing Record 40 of Set 7 | zaterechnyy
# Processing Record 41 of Set 7 | yambio
# Processing Record 42 of Set 7 | shiyan
# Processing Record 43 of Set 7 | kamaishi
# Processing Record 44 of Set 7 | samarai
# Processing Record 45 of Set 7 | abnub
# Processing Record 46 of Set 7 | honiara
# Processing Record 47 of Set 7 | xilagani
# Processing Record 48 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 7 | inhambane
# Processing Record 50 of Set 7 | souillac
# Processing Record 1 of Set 8 | muros
# Processing Record 2 of Set 8 | zapadnaya dvina
# Processing Record 3 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 8 | yar-sale
# Processing Record 5 of Set 8 | aykhal
# Processing Record 6 of Set 8 | tshela
# Processing Record 7 of Set 8 | nevelsk
# Processing Record 8 of Set 8 | palafrugell
# Processing Record 9 of Set 8 | ormond beach
# Processing Record 10 of Set 8 | doka
# Processing Record 11 of Set 8 | matamoros
# Processing Record 12 of Set 8 | verkhoyansk
# Processing Record 13 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 14 of Set 8 | lata
# Processing Record 15 of Set 8 | garowe
# Processing Record 16 of Set 8 | tono
# Processing Record 17 of Set 8 | bethel
# Processing Record 18 of Set 8 | corinth
# Processing Record 19 of Set 8 | moussoro
# Processing Record 20 of Set 8 | dudinka
# Processing Record 21 of Set 8 | primero de marzo
# Processing Record 22 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 8 | northam
# Processing Record 24 of Set 8 | dunnville
# Processing Record 25 of Set 8 | new plymouth
# Processing Record 26 of Set 8 | filingue
# Processing Record 27 of Set 8 | pocone
# Processing Record 28 of Set 8 | sao sebastiao
# Processing Record 29 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 8 | mahebourg
# Processing Record 31 of Set 8 | kankon
# Processing Record 32 of Set 8 | aras
# Processing Record 33 of Set 8 | kingsland
# Processing Record 34 of Set 8 | freeport
# Processing Record 35 of Set 8 | chumikan
# Processing Record 36 of Set 8 | namatanai
# Processing Record 37 of Set 8 | iqaluit
# Processing Record 38 of Set 8 | kiunga
# Processing Record 39 of Set 8 | bereda
# Processing Record 40 of Set 8 | aschersleben
# Processing Record 41 of Set 8 | la roda
# Processing Record 42 of Set 8 | shimoda
# Processing Record 43 of Set 8 | zhovtneve
# Processing Record 44 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 8 | pochutla
# Processing Record 46 of Set 8 | soma
# Processing Record 47 of Set 8 | bathsheba
# Processing Record 48 of Set 8 | sandwick
# Processing Record 49 of Set 8 | roald
# Processing Record 50 of Set 8 | yazman
# Processing Record 1 of Set 9 | siuna
# Processing Record 2 of Set 9 | jian
# Processing Record 3 of Set 9 | clyde river
# Processing Record 4 of Set 9 | gouloure
# Processing Record 5 of Set 9 | puerto quijarro
# Processing Record 6 of Set 9 | lasa
# Processing Record 7 of Set 9 | guasdualito
# Processing Record 8 of Set 9 | callaway
# Processing Record 9 of Set 9 | luanda
# Processing Record 10 of Set 9 | asau
# Processing Record 11 of Set 9 | visaginas
# Processing Record 12 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 9 | bahia blanca
# Processing Record 14 of Set 9 | kahului
# Processing Record 15 of Set 9 | pisco
# Processing Record 16 of Set 9 | tautira
# Processing Record 17 of Set 9 | pozo colorado
# Processing Record 18 of Set 9 | beringovskiy
# Processing Record 19 of Set 9 | boende
# Processing Record 20 of Set 9 | mount isa
# Processing Record 21 of Set 9 | lyndon
# Processing Record 22 of Set 9 | poli
# Processing Record 23 of Set 9 | linjiang
# Processing Record 24 of Set 9 | raudeberg
# Processing Record 25 of Set 9 | coos bay
# Processing Record 26 of Set 9 | thompson
# Processing Record 27 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 9 | shache
# Processing Record 29 of Set 9 | moron
# Processing Record 30 of Set 9 | maceio
# Processing Record 31 of Set 9 | grand gaube
# Processing Record 32 of Set 9 | sao felix do xingu
# Processing Record 33 of Set 9 | simpang rengam
# City not found. Skipping...
# Processing Record 34 of Set 9 | saint-augustin
# Processing Record 35 of Set 9 | jardim
# Processing Record 36 of Set 9 | port macquarie
# Processing Record 37 of Set 9 | high rock
# Processing Record 38 of Set 9 | witu
# Processing Record 39 of Set 9 | voi
# Processing Record 40 of Set 9 | olafsvik
# Processing Record 41 of Set 9 | olinda
# Processing Record 42 of Set 9 | jumla
# Processing Record 43 of Set 9 | griffin
# Processing Record 44 of Set 9 | paka
# Processing Record 45 of Set 9 | chalchihuites
# Processing Record 46 of Set 9 | mackay
# Processing Record 47 of Set 9 | filimonovo
# Processing Record 48 of Set 9 | russell
# Processing Record 49 of Set 9 | yaan
# Processing Record 50 of Set 9 | kilrush
# Processing Record 1 of Set 10 | horsham
# Processing Record 2 of Set 10 | skelleftea
# Processing Record 3 of Set 10 | greytown
# Processing Record 4 of Set 10 | henties bay
# Processing Record 5 of Set 10 | mpika
# Processing Record 6 of Set 10 | magan
# Processing Record 7 of Set 10 | assiniboia
# Processing Record 8 of Set 10 | santa cruz de la palma
# Processing Record 9 of Set 10 | penticton
# Processing Record 10 of Set 10 | iquitos
# Processing Record 11 of Set 10 | chicama
# Processing Record 12 of Set 10 | campoverde
# Processing Record 13 of Set 10 | niltepec
# Processing Record 14 of Set 10 | lixourion
# Processing Record 15 of Set 10 | saint-joseph
# Processing Record 16 of Set 10 | fagersta
# Processing Record 17 of Set 10 | staunton
# Processing Record 18 of Set 10 | emba
# Processing Record 19 of Set 10 | lahat
# Processing Record 20 of Set 10 | tiarei
# Processing Record 21 of Set 10 | phan thiet
# Processing Record 22 of Set 10 | afikpo
# Processing Record 23 of Set 10 | ilulissat
# Processing Record 24 of Set 10 | vallenar
# Processing Record 25 of Set 10 | dryden
# Processing Record 26 of Set 10 | lubango
# Processing Record 27 of Set 10 | abu samrah
# Processing Record 28 of Set 10 | lucea
# Processing Record 29 of Set 10 | sola
# Processing Record 30 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 31 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 10 | lagoa
# Processing Record 33 of Set 10 | haapu
# City not found. Skipping...
# Processing Record 34 of Set 10 | sinjar
# Processing Record 35 of Set 10 | catalina
# Processing Record 36 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 10 | pinillos
# Processing Record 38 of Set 10 | yumen
# Processing Record 39 of Set 10 | omboue
# Processing Record 40 of Set 10 | bindura
# Processing Record 41 of Set 10 | anzio
# Processing Record 42 of Set 10 | portsmouth
# Processing Record 43 of Set 10 | lubumbashi
# Processing Record 44 of Set 10 | atka
# City not found. Skipping...
# Processing Record 45 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 10 | palmer
# Processing Record 47 of Set 10 | flinders
# Processing Record 48 of Set 10 | asia
# Processing Record 49 of Set 10 | cedar city
# Processing Record 50 of Set 10 | sao filipe
# Processing Record 1 of Set 11 | virginia beach
# Processing Record 2 of Set 11 | kabare
# Processing Record 3 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 4 of Set 11 | kulhudhuffushi
# Processing Record 5 of Set 11 | general pico
# Processing Record 6 of Set 11 | elayirampannai
# Processing Record 7 of Set 11 | hasilpur
# Processing Record 8 of Set 11 | aktau
# Processing Record 9 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 10 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 11 of Set 11 | manresa
# Processing Record 12 of Set 11 | bilibino
# Processing Record 13 of Set 11 | ellensburg
# Processing Record 14 of Set 11 | boyolangu
# Processing Record 15 of Set 11 | ribeira grande
# Processing Record 16 of Set 11 | jalu
# Processing Record 17 of Set 11 | auki
# Processing Record 18 of Set 11 | bengkulu
# Processing Record 19 of Set 11 | praia da vitoria
# Processing Record 20 of Set 11 | manay
# Processing Record 21 of Set 11 | geraldton
# Processing Record 22 of Set 11 | carballo
# Processing Record 23 of Set 11 | opuwo
# Processing Record 24 of Set 11 | marrakesh
# Processing Record 25 of Set 11 | tirumullaivasal
# Processing Record 26 of Set 11 | tsabong
# Processing Record 27 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 11 | nieuwpoort
# Processing Record 29 of Set 11 | hay river
# Processing Record 30 of Set 11 | ivybridge
# Processing Record 31 of Set 11 | verkhnyaya toyma
# Processing Record 32 of Set 11 | acarau
# Processing Record 33 of Set 11 | tigil
# Processing Record 34 of Set 11 | fecamp
# Processing Record 35 of Set 11 | vanderhoof
# Processing Record 36 of Set 11 | havre
# Processing Record 37 of Set 11 | urumqi
# Processing Record 38 of Set 11 | hambantota
# Processing Record 39 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 11 | gutierrez zamora
# Processing Record 41 of Set 11 | wharton
# Processing Record 42 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 11 | marawi
# Processing Record 44 of Set 11 | ancud
# Processing Record 45 of Set 11 | dmytrivka
# Processing Record 46 of Set 11 | rio grande
# Processing Record 47 of Set 11 | manicore
# Processing Record 48 of Set 11 | manado
# Processing Record 49 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 11 | cairns
# Processing Record 1 of Set 12 | alice springs
# Processing Record 2 of Set 12 | iralaya
# Processing Record 3 of Set 12 | jiazi
# Processing Record 4 of Set 12 | arman
# Processing Record 5 of Set 12 | svolvaer
# Processing Record 6 of Set 12 | indramayu
# Processing Record 7 of Set 12 | vostok
# Processing Record 8 of Set 12 | mocuba
# Processing Record 9 of Set 12 | sal rei
# Processing Record 10 of Set 12 | geilo
# Processing Record 11 of Set 12 | kwinana
# Processing Record 12 of Set 12 | masterton
# Processing Record 13 of Set 12 | somerset
# Processing Record 14 of Set 12 | buala
# Processing Record 15 of Set 12 | egvekinot
# Processing Record 16 of Set 12 | tambun
# Processing Record 17 of Set 12 | teixoso
# Processing Record 18 of Set 12 | margate
# Processing Record 19 of Set 12 | vytegra
# Processing Record 20 of Set 12 | tromso
# Processing Record 21 of Set 12 | miguel hidalgo
# Processing Record 22 of Set 12 | kungurtug
# Processing Record 23 of Set 12 | dzaoudzi
# Processing Record 24 of Set 12 | la ligua
# Processing Record 25 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 12 | kaseda
# Processing Record 27 of Set 12 | mbala
# Processing Record 28 of Set 12 | loubomo
# Processing Record 29 of Set 12 | chimbote
# Processing Record 30 of Set 12 | los llanos de aridane
# Processing Record 31 of Set 12 | suba
# Processing Record 32 of Set 12 | impfondo
# Processing Record 33 of Set 12 | krasnystaw
# Processing Record 34 of Set 12 | iracoubo
# Processing Record 35 of Set 12 | tianpeng
# Processing Record 36 of Set 12 | waddan
# Processing Record 37 of Set 12 | vila velha
# Processing Record 38 of Set 12 | pangkalanbuun
# Processing Record 39 of Set 12 | talnakh
# Processing Record 40 of Set 12 | pindiga
# Processing Record 41 of Set 12 | matca
# Processing Record 42 of Set 12 | wa
# City not found. Skipping...
# Processing Record 43 of Set 12 | port lincoln
# Processing Record 44 of Set 12 | sosva
# Processing Record 45 of Set 12 | kaeo
# Processing Record 46 of Set 12 | drumheller
# Processing Record 47 of Set 12 | delcevo
# Processing Record 48 of Set 12 | okhotsk
# Processing Record 49 of Set 12 | pimentel
# Processing Record 50 of Set 12 | trairi
# Processing Record 1 of Set 13 | salinopolis
# Processing Record 2 of Set 13 | mayo
# Processing Record 3 of Set 13 | paamiut
# Processing Record 4 of Set 13 | balabac
# Processing Record 5 of Set 13 | gorey
# Processing Record 6 of Set 13 | fare
# Processing Record 7 of Set 13 | la rioja
# Processing Record 8 of Set 13 | lakes entrance
# Processing Record 9 of Set 13 | kysyl-syr
# Processing Record 10 of Set 13 | kalianget
# Processing Record 11 of Set 13 | goma
# Processing Record 12 of Set 13 | byron bay
# Processing Record 13 of Set 13 | port-gentil
# Processing Record 14 of Set 13 | turukhansk
# Processing Record 15 of Set 13 | saquarema
# Processing Record 16 of Set 13 | perivolion
# Processing Record 17 of Set 13 | wad rawah
# Processing Record 18 of Set 13 | vanimo
# Processing Record 19 of Set 13 | atikokan
# Processing Record 20 of Set 13 | ust-kulom
# Processing Record 21 of Set 13 | sakakah
# Processing Record 22 of Set 13 | salalah
# Processing Record 23 of Set 13 | hofn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 571

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0                     Torbay      CA  47.6666  -52.7314     81.37        78
# 1         Comodoro Rivadavia      AR -45.8667  -67.5000     51.66        62
# 2                  Cape Town      ZA -33.9258   18.4232     62.11        66
# 3                    Rikitea      PF -23.1203 -134.9692     74.48        75
# 4                  Jamestown      US  42.0970  -79.2353     72.30        65
# 5                     Hobart      AU -42.8794  147.3294     43.27        86
# 6                      Kieta      PG  -6.2167  155.6333     78.24        85
# 7  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     48.79       100
# 8                East London      ZA -33.0153   27.9116     61.74        82
# 9                  Esperance      AU -33.8667  121.9000     49.84        87
#
#    Cloudiness  Wind Speed Current description
# 0          40        3.44          light rain
# 1           0        3.44           clear sky
# 2           0        1.01           clear sky
# 3           1       13.38           clear sky
# 4           1        3.00           clear sky
# 5          90        4.00     overcast clouds
# 6          82        4.12          light rain
# 7          20        4.47          few clouds
# 8           0       10.36           clear sky
# 9           0        8.08           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
